# %%
# %matplotlib notebook 
# %run ../lib/startup.py

# %%
# datafile management with pytables and h5py defaults to 
import tables
db = tables.open_file("test.h5", mode="a", title="testing")
db.flush()

# %%
name = 'third'
db_entry = db.create_array(db.root,name, np.array([1,3]), '%s spectrum' %name)
db_entry.attrs['IT'] = 15
db.flush()

# %%
for spectrum in db.root:  
    print(spectrum)
    plt.plot(np.array(spectrum.read()))
# Out:
# /first (Array(2,)) 'first spectrum'
# <img src="data:image/png;base64,..." width="640">
# /second (Array(2,)) 'second spectrum'
# /third (Array(2,)) 'third spectrum'

# %%
plt.plot(db.root.third.read()*2)

# %%
plt.scatter(second.read()[0], second.read()[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-59-36a5826fcfb0> in <module>()
# ----> 1 plt.scatter(second.read()[0], second.read()[2])
#
# IndexError: list index out of range

# %%
db.close()
